# %% [markdown]
# > Offline RL 算法的核心是在优化奖励的同时，约束策略使其不过于偏离数据集中的行为。“请参考这些例子（及其后果），找出一个能获得最高总分的策略，但不要做太出格的尝试”。
# - data-driven RL methods
# - on-policy rl vs. off-policy rl (q-learning)
#     - off-policy rl: buffered version of on-policy rl
